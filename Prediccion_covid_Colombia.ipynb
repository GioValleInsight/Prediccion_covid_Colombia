# %% [markdown]
# <a href="https://colab.research.google.com/github/GioValleInsight/Prediccion_covid_Colombia/blob/master/Prediccion_covid_Colombia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import folium 
from folium import plugins
plt.rcParams['figure.figsize'] = 10, 12
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df= pd.read_excel('/content/Casos_positivos_de_COVID-19_en_Colombia-_1-05_.xlsx',parse_dates=['Fecha de notificación'])
df
# Out:
#       ID de caso  ...         Fecha recuperado
# 0              1  ...  2020-03-13T00:00:00.000
# 1              2  ...  2020-03-19T00:00:00.000
# 2              3  ...  2020-03-15T00:00:00.000
# 3              4  ...  2020-03-26T00:00:00.000
# 4              5  ...  2020-03-23T00:00:00.000
# ...          ...  ...                      ...
# 7001        7002  ...                    -   -
# 7002        7003  ...                    -   -
# 7003        7004  ...                    -   -
# 7004        7005  ...                    -   -
# 7005        7006  ...                    -   -
#
# [7006 rows x 14 columns]

# %%
total_Colombia=df['ID de caso'].count()
total_Colombia
# Out:
# 7006

# %%
gk = df.groupby('Ciudad de ubicación')

# %%
bogota = gk.get_group('Bogotá D.C.')

# %%
bogota
# Out:
#       ID de caso  ...         Fecha recuperado
# 0              1  ...  2020-03-13T00:00:00.000
# 7              8  ...  2020-03-21T00:00:00.000
# 8              9  ...  2020-03-23T00:00:00.000
# 9             10  ...  2020-03-21T00:00:00.000
# 10            11  ...  2020-03-31T00:00:00.000
# ...          ...  ...                      ...
# 7001        7002  ...                    -   -
# 7002        7003  ...                    -   -
# 7003        7004  ...                    -   -
# 7004        7005  ...                    -   -
# 7005        7006  ...                    -   -
#
# [2772 rows x 14 columns]

# %%
total_bogota=bogota['ID de caso'].count()

# %%
total_bogota
# Out:
# 2772
